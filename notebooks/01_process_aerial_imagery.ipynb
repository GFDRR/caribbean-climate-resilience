# %% [markdown]
# ## Imports and Setup

# %%
import os 
os.chdir('../')
from utils import data_sampler
from utils import download_utils
import geopandas as gpd
import pandas as pd
import yaml

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Parameters

# %%
config_file = "configs/config_VCT.yaml"
with open(config_file, 'r') as stream:
    config = yaml.safe_load(stream)

# %% [markdown]
# ## Generate Samples

# %%
ds = data_sampler.DataSampler(version=2, n_samples=500, **config)
# Out:
# INFO:root:Loading buildings for VCT...
# INFO:root:Generating 500 x 500 grid for VCT...
# INFO:root:Reading grid file C:\Users\Isabelle\Documents\GFDRR\dep\caribbean-climate-resilience\data/aerial/vector/VCT\grid_VCT.geojson
# INFO:root:Sampling 500 grid tiles for VCT...
# INFO:root:Reading grid sample file: C:\Users\Isabelle\Documents\GFDRR\dep\caribbean-climate-resilience\data/aerial/vector/VCT\ann2_grid_VCT.geojson
# Processing 25447 image tiles: 100%|████████████████████████████████████████████| 25447/25447 [00:08<00:00, 3179.23it/s]
# INFO:root:Building tiles saved to C:\Users\Isabelle\Documents\GFDRR\dep\caribbean-climate-resilience\data/aerial/raster/VCT\tiles_VCT.
# INFO:pyogrio._io:Created 31,141 records

# %% [markdown]
# ## Visualize Sampled Grids

# %%
ds.plot_samples()
# Out:
# INFO:root:Total number of building samples: 14756/44530
# INFO:root:Urban/rural ratio: rurban
# urban    8383
# rural    6373
# Name: count, dtype: int64
