# %% [markdown]
# ## Imports and Setup

# %%
import os 
os.chdir('../')
from utils import data_sampler
from utils import download_utils
import geopandas as gpd
import pandas as pd
import yaml

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Parameters

# %%
config_file = "configs/config_GRD.yaml"
with open(config_file, 'r') as stream:
    config = yaml.safe_load(stream)

# %% [markdown]
# ## Generate Samples

# %%
ds = data_sampler.DataSampler(**config)
# Out:
# INFO:root:Loading buildings for GRD...
# INFO:root:Generating 500 x 500 grid for GRD...
# INFO:pyogrio._io:Created 1,068 records
# INFO:root:500 x 500 grids for GRD saved to C:\Users\Isabelle\Documents\GFDRR\dep\caribbean-building-attributes\data/aerial/vector/GRD\grid_GRD.geojson
# INFO:root:Sampling 100 grid tiles for GRD...
# INFO:pyogrio._io:Created 100 records
# INFO:root:Grid samples saved to C:\Users\Isabelle\Documents\GFDRR\dep\caribbean-building-attributes\data/aerial/vector/GRD\ann_grid_GRD.geojson
# Processing 3578 image tiles: 100%|█████████████████████████████████████████████████| 3578/3578 [08:50<00:00,  6.74it/s]
# INFO:root:Building tiles saved to C:\Users\Isabelle\Documents\GFDRR\dep\caribbean-building-attributes\data/aerial/raster/GRD\tiles_GRD.
# INFO:pyogrio._io:Created 3,578 records
# INFO:root:Building sample geojson saved to C:\Users\Isabelle\Documents\GFDRR\dep\caribbean-building-attributes\data/aerial/vector/GRD\tiles_GRD.geojson.

# %% [markdown]
# ## Visualize Sampled Grids

# %%
ds.plot_samples()
# Out:
# INFO:root:Total number of building samples: 3578/48394
# INFO:root:Urban/rural ratio: rurban
# urban    2008
# rural    1570
# Name: count, dtype: int64
